# %%
rm(list = ls())

# %%
# Importar archivos TXT ---------------------------------------------------
library(readr)
medidas_cuerpo <- read_delim("C:/Users/PC/seminario_R/Datos/medidas_cuerpo.txt", delim = "\t", escape_double = FALSE, comment = "#", trim_ws = TRUE)
# Out:
# Parsed with column specification:
# cols(
#   edad = col_double(),
#   peso = col_double(),
#   altura = col_double(),
#   sexo = col_character(),
#   muneca = col_double(),
#   biceps = col_double()
# )

# %%
medidas_cuerpo
# Out:
#    edad peso altura sexo   muneca biceps
# 1  43   87.3 188.0  Hombre 12.2   35.8
# 2  65   80.0 174.0  Hombre 12.0   35.0
# 3  45   82.3 176.5  Hombre 11.2   38.5
# 4  37   73.6 180.3  Hombre 11.2   32.2
# 5  55   74.1 167.6  Hombre 11.8   32.9
# 6  33   85.9 188.0  Hombre 12.4   38.5
# 7  25   73.2 180.3  Hombre 10.6   38.3
# 8  35   76.3 167.6  Hombre 11.3   35.0
# 9  28   65.9 183.0  Hombre 10.2   32.1
# 10 26   90.9 183.0  Hombre 12.0   40.4
# 11 43   89.1 179.1  Hombre 11.3   36.5
# 12 30   62.3 170.2  Hombre 11.5   34.2
# 13 26   82.7 177.8  Hombre 11.5   35.2
# 14 51   79.1 179.1  Hombre 11.8   34.0
# 15 30   98.2 190.5  Hombre 10.7   34.8
# 16 24   84.1 177.8  Hombre 11.5   38.6
# 17 35   83.2 180.3  Hombre 11.1   36.4
# 18 37   83.2 180.3  Hombre 10.5   34.0
# 19 22   51.6 161.2  Mujer   9.2   24.3
# 20 20   59.0 167.5  Mujer   9.9   27.8
# 21 19   49.2 159.5  Mujer   8.9   24.0
# 22 25   63.0 157.0  Mujer   9.5   28.0
# 23 21   53.6 155.8  Mujer   9.1   26.9
# ...

# %%
medidas_cuerpo <- read_delim("C:/Users/PC/seminario_R/Datos/medidas_cuerpo.txt",delim = "\t", escape_double = FALSE,col_types = cols(sexo = col_factor(levels = c("Mujer","Hombre"))), comment = "#", trim_ws = TRUE)

# %%
library(readxl)
url <- "https://www.lock5stat.com/datasets3e/NutritionStudy.xlsx"
destfile <- "NutritionStudy.xlsx"
curl::curl_download(url, destfile)
NutritionStudy <- read_excel(destfile)

# %%
NutritionStudy
# Out:
#     ID  Age Smoke Quetelet Vitamin Calories Fat   Fiber Alcohol Cholesterol
# 1    1  64  No    21.4838  1       1298.8    57.0  6.3   0.0    170.3
# 2    2  76  No    23.8763  1       1032.5    50.1 15.8   0.0     75.8
# 3    3  38  No    20.0108  2       2372.3    83.6 19.1  14.1    257.9
# 4    4  40  No    25.1406  3       2449.5    97.5 26.5   0.5    332.6
# 5    5  72  No    20.9850  1       1952.1    82.6 16.2   0.0    170.8
# 6    6  40  No    27.5214  3       1366.9    56.0  9.6   1.3    154.6
# 7    7  65  No    22.0115  2       2213.9    52.0 28.7   0.0    255.1
# 8    8  58  No    28.7570  1       1595.6    63.4 10.9   0.0    214.1
# 9    9  35  No    23.0766  3       1800.5    57.8 20.3   0.6    233.6
# 10  10  55  No    34.9699  3       1263.6    39.6 15.5   0.0    171.9
# 11  11  66  No    20.9465  1       1460.8    58.0 18.2   1.0    137.4
# 12  12  40  No    36.4316  2       1638.2    49.3 14.9   0.0    130.7
# ...

# %%
medidas_cuerpo
# Out:
#    edad peso altura sexo   muneca biceps
# 1  43   87.3 188.0  Hombre 12.2   35.8
# 2  65   80.0 174.0  Hombre 12.0   35.0
# 3  45   82.3 176.5  Hombre 11.2   38.5
# 4  37   73.6 180.3  Hombre 11.2   32.2
# 5  55   74.1 167.6  Hombre 11.8   32.9
# 6  33   85.9 188.0  Hombre 12.4   38.5
# 7  25   73.2 180.3  Hombre 10.6   38.3
# 8  35   76.3 167.6  Hombre 11.3   35.0
# 9  28   65.9 183.0  Hombre 10.2   32.1
# 10 26   90.9 183.0  Hombre 12.0   40.4
# 11 43   89.1 179.1  Hombre 11.3   36.5
# 12 30   62.3 170.2  Hombre 11.5   34.2
# 13 26   82.7 177.8  Hombre 11.5   35.2
# 14 51   79.1 179.1  Hombre 11.8   34.0
# 15 30   98.2 190.5  Hombre 10.7   34.8
# 16 24   84.1 177.8  Hombre 11.5   38.6
# 17 35   83.2 180.3  Hombre 11.1   36.4
# 18 37   83.2 180.3  Hombre 10.5   34.0
# 19 22   51.6 161.2  Mujer   9.2   24.3
# 20 20   59.0 167.5  Mujer   9.9   27.8
# 21 19   49.2 159.5  Mujer   8.9   24.0
# 22 25   63.0 157.0  Mujer   9.5   28.0
# 23 21   53.6 155.8  Mujer   9.1   26.9
# ...
