# %% [markdown]
# # Hopfield Network

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Ejemplo
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Cuando es la misma salida fundamental se dice que la neurona fue capaz de aprender a Y1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Veamos si la red se esta comprobando bien

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# en la primera iteracion ypw no es igual a yp=!s entonces no es estable, en la segunda ya es estable

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
